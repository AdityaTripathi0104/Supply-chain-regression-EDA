# %%
# %%writefile .gitignore
#
# #Ignore data files
# *.csv
# *.xlsx
#
# #Ignore Jupyter Notebook checkpoints
# .ipynb_checkpoints/
#
# #Ignore Python environments
# venv/
# __pycache__/
# Out:
# Writing .gitignore
